# %% [markdown]
# # NetworkX Introduction - Lab
#
# ## Introduction
#
# In this lab, you'll practice some of the introductory skills for creating graphs using the NetworkX library introduced in the previous lesson. To do this, you'll create a graph to visualize users and businesses from yelp reviews.
#
# ## Objectives
#
# In this lab you will:
#
# - Create basic network graphs with networkx
# - Add nodes and edges to networkx graphs
# - Visualize network graphs with networkx
#
# ## Import the Data
#
# To start, import the data stored in the file `'Yelp_reviews.csv'`.

# %%
# Your code here
import pandas as pd

df = pd.read_csv('Yelp_reviews.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   business_id  76 non-null     object
#  1   date         76 non-null     object
#  2   review_id    76 non-null     object
#  3   stars        76 non-null     int64
#  4   text         76 non-null     object
#  5   type         76 non-null     object
#  6   user_id      76 non-null     object
#  7   cool         76 non-null     int64
#  8   useful       76 non-null     int64
#  9   funny        76 non-null     int64
# dtypes: int64(4), object(6)
# memory usage: 6.1+ KB

# %% [markdown]
# ## Creating a Graph
#
# Now, create an initial graph!

# %%
# Your code here
import networkx as nx

G = nx.Graph()

# %% [markdown]
# ## Adding Nodes
#
# Create a node for each user and each business in the dataset. Networks with multiple node types like this are called **bimodal networks**.
#
# Optionally, go further by creating a list of colors for when you visualize the graph. If you do this, append the color "green" to your color list every time you add a user node and append the color "blue" to your color list every time you add a business node.

# %%
# Your code here

# for idx, r in df.iterrows():
#     print(f"uid: {r.user_id}, bid: {r.business_id}")

colors = []
for uid in df.user_id.unique():
    G.add_node(f"uid_{uid}")
    colors.append("green")
    
for bid in df.business_id.unique():
    G.add_node(f"bid_{bid}")
    colors.append("blue")

# %% [markdown]
# ## Adding Edges
#
# Next, iterate through the dataset and create an edge between users and the businesses they have reviewed.

# %%
# Your code here
for idx, r in df.iterrows():
    G.add_edge(f"uid_{r.user_id}", f"bid_{r.business_id}")

# %% [markdown]
# ## Visualizing the Graph
#
# Finally, create a visualization of your network. If you chose to color your nodes, pass the list of colors through the optional `node_color` parameter.

# %%
# Your code here
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,10))
nx.draw(G, with_labels=True, node_color=colors, node_size=500, alpha=0.7)
plt.show()

# %% [markdown]
# ## Summary
#
# Nice work! In this lab you created an initial network to visualize a bimodal network of businesses and yelp reviewers!
